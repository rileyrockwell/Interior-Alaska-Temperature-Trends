# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = '/workspaces/Interior-Alaska-Temperature-Trends/data/ghcnm.tavg.v4.0.1.20260323.qcu.dat'

df = pd.read_fwf(
    file_path,
    widths=[11, 4] + [5]*12,
    header=None
)

cols = ['station_id', 'year'] + [f'm{i}' for i in range(1, 13)]
df.columns = cols

df = df[df['station_id'] == 'USW00026411']

df = df.melt(
    id_vars=['station_id', 'year'],
    var_name='month',
    value_name='temp'
)

df['month'] = df['month'].str.replace('m', '').astype(int)

df['temp'] = df['temp'].replace(-9999, pd.NA)

df['temp'] = df['temp'] / 100.0

df['date'] = pd.to_datetime(dict(year=df.year, month=df.month, day=1))
df = df.set_index('date').sort_index()

df = df[['temp']]
df = df.dropna()

### confirm ###

print(df.head())
print(df.tail())
print(df.describe())

plt.figure()
df['temp'].plot()
plt.title('Fairbanks Monthly Temperature')
plt.show()

# %%
cols = ['station_id', 'year'] + [f'm{i}' for i in range(1, 13)]
df.columns = cols

# %%
df = df[df['station_id'] == 'USW00026411']

# %%
df = df.melt(
    id_vars=['station_id', 'year'],
    var_name='month',
    value_name='temp'
)

# %%
df['month'] = df['month'].str.replace('m', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['month'] = df['month'].str.replace('m', '').astype(int)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# ...

# %%
df['temp'] = df['temp'].replace(-9999, pd.NA)

# %%
df['temp'] = df['temp'] / 100.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/computation/expressions.py:243, in evaluate(op, left_op, right_op, use_numexpr)
#     241     if use_numexpr:
#     242         # error: "None" not callable
# --> 243         return _evaluate(op, op_str, left_op, right_op)  # type: ignore[misc]
#     244 return _evaluate_standard(op, op_str, left_op, right_op)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/computation/expressions.py:74, in _evaluate_standard(op, op_str, left_op, right_op)
#      73     _store_test_result(False)
# ...
